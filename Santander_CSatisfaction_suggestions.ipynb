# %% [markdown]
# ## Santander Bank Custumer Satisfaction
#
# ![front_page.png](attachment:front_page.png)
#
#
# Customer satisfaction is a key measure of success. Unhappy customers don't stick around. What's more, unhappy customers rarely voice their dissatisfaction before leaving.
#
# In this tutorial we will try to identify dissatisfied customers early in their relationship.
#
# You'll work with hundreds of anonymized features to predict if a customer is satisfied or dissatisfied with their banking experience.
#
# Results will be evaluated using the area under the ROC curve between the predicted probability and the observed target.
#
#
# # Data
#
# You are provided with an anonymized dataset containing a large number of numeric variables. The "TARGET" column is the variable to predict. It equals ***one for unsatisfied customers***  and ***0 for satisfied customers***.
#
# The task is to predict the probability that each customer in the test set is an unsatisfied customer.
#
# File descriptions
#
# train.csv - the training set including the target

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Santander_CustumerSatisfaction.ipynb test.csv
# front_page.png                       train.csv

# %%
#Load the data
df= pd.read_csv('train.csv')

# %%
#EDA, how many features and data? Statistics? Explain the data

# %%
#summarize the rows with missing values

# %%
# remove constant columns
remove = []
for col in df.columns:
    if df[col].std() == 0:
        remove.append(col)

# %%
remove
# Out:
# ['ind_var2_0',
#  'ind_var2',
#  'ind_var27_0',
#  'ind_var28_0',
#  'ind_var28',
#  'ind_var27',
#  'ind_var41',
#  'ind_var46_0',
#  'ind_var46',
#  'num_var27_0',
#  'num_var28_0',
#  'num_var28',
#  'num_var27',
#  'num_var41',
#  'num_var46_0',
#  'num_var46',
#  'saldo_var28',
#  'saldo_var27',
#  'saldo_var41',
#  'saldo_var46',
#  'imp_amort_var18_hace3',
#  'imp_amort_var34_hace3',
#  'imp_reemb_var13_hace3',
#  'imp_reemb_var33_hace3',
#  'imp_trasp_var17_out_hace3',
#  'imp_trasp_var33_out_hace3',
#  'num_var2_0_ult1',
#  'num_var2_ult1',
#  'num_reemb_var13_hace3',
#  'num_reemb_var33_hace3',
#  'num_trasp_var17_out_hace3',
#  'num_trasp_var33_out_hace3',
#  'saldo_var2_ult1',
#  'saldo_medio_var13_medio_hace3']

# %%
#drop them
df.drop(remove, axis=1, inplace=True)

# %%
## remove duplicated columns
remove = []
c = df.columns
for i in range(len(c)-1):
    v = df[c[i]].values
    for j in range(i+1,len(c)):
        if np.array_equal(v,df[c[j]].values):
            remove.append(c[j])

# %%
remove
# Out:
# ['ind_var29_0',
#  'ind_var29',
#  'ind_var13_medio',
#  'ind_var18',
#  'ind_var26',
#  'ind_var25',
#  'ind_var32',
#  'ind_var34',
#  'ind_var37',
#  'ind_var39',
#  'num_var29_0',
#  'num_var29',
#  'num_var13_medio',
#  'num_var18',
#  'num_var26',
#  'num_var25',
#  'num_var32',
#  'num_var34',
#  'num_var37',
#  'num_var39',
#  'saldo_var29',
#  'saldo_medio_var13_medio_ult1',
#  'delta_num_reemb_var13_1y3',
#  'delta_num_reemb_var17_1y3',
#  'delta_num_reemb_var33_1y3',
#  'delta_num_trasp_var17_in_1y3',
#  'delta_num_trasp_var17_out_1y3',
#  'delta_num_trasp_var33_in_1y3',
#  'delta_num_trasp_var33_out_1y3']

# %%
#drop them
df.drop(remove, axis=1, inplace=True)

# %% [markdown]
# ---
#
# ## Train and test the model
#
# ---

# %%
#prepare data
y_whole = df['TARGET'].values
X_whole = df.drop(['ID','TARGET'], axis=1).values

print (X_whole.shape)
print (y_whole.shape)
# Out:
# (76020, 306)
# (76020,)

# %%
#Preprocess , i.e scale the dataset

# %%
#split in train and test
X_train = 
y_train = 
X_val = 
y_val =
# Out:
# (40000, 306)
# (40000,)
# (15000, 306)
# (15000,)

# %% [markdown]
# ### Choose a ML algorithm, train and test

# %%
#try with SVM

# %% [markdown]
# ## Try another ML

# %%
#from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#How good is your result? look at the required metric, AUC
from sklearn.metrics import roc_auc_score
print('Overall AUC:', roc_auc_score(y_train, clf.predict_proba(X_train)[:,1]))
# Out:
# Overall AUC: 0.8930292883197978

# %%
#visualize the curve for both validation and training. Make considerations
from sklearn.metrics import roc_curve
fpr, tpr, th = roc_curve(y_train, clf.predict_proba(X_val)[:,1])
plt.plot(fpr, tpr)
# Out:
# auc =  0.8930292883197978

# %% [markdown]
# ---
#
# # Try Unsupervised
#
# ---

# %%
#test now a kmean 2D
import seaborn as sns
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(X_whole[:4000,:].T)
